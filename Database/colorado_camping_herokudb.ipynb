# %%
import pandas as pd
from sqlalchemy import create_engine
import os

import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import psycopg2
from sqlalchemy import inspect

# %%
pg_user = 'postgres'
pg_pwd = 'postgres'
pg_port = "5432"
database = 'dfcl071kkkkeuj'
url = f"postgresql://{pg_user}:{pg_pwd}@localhost:{pg_port}/{database}"
engine = create_engine(f'{url}')
# reflect an existing database into a new model

insp=inspect(engine)

print(insp.get_table_names())

Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
nps = Base.classes.geocode_info

session = Session(engine)

result=session.query(nps)\
.filter(nps.FacilityID==231860).all()

for each_result in result:
    print(each_result.FacilityLatitude)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "dfcl071kkkkeuj" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-7504f9c49a35> in <module>
#       7 # reflect an existing database into a new model
#       8
# ----> 9 insp=inspect(engine)
#      10
#      11 print(insp.get_table_names())
#
# ~\anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _insp(bind)
#     137     @inspection._inspects(Connectable)
#     138     def _insp(bind):
# --> 139         return Inspector.from_engine(bind)
#     140
#     141     @property
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in from_engine(cls, bind)
#     132         """
#     133         if hasattr(bind.dialect, "inspector"):
# --> 134             return bind.dialect.inspector(bind)
#     135         return Inspector(bind)
#     136
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\base.py in __init__(self, conn)
#    2399 class PGInspector(reflection.Inspector):
#    2400     def __init__(self, conn):
# -> 2401         reflection.Inspector.__init__(self, conn)
#    2402
#    2403     def get_table_oid(self, table_name, schema=None):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in __init__(self, bind)
#     106         if self.engine is bind:
#     107             # if engine, ensure initialized
# --> 108             bind.connect().close()
#     109
#     110         self.dialect = self.engine.dialect
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2261         """
#    2262
# -> 2263         return self._connection_cls(self, **kwargs)
#    2264
#    2265     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2367
#    2368         """
# -> 2369         return self._wrap_pool_connect(
#    2370             self.pool.unique_connection, _connection
#    2371         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "dfcl071kkkkeuj" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# # Store CSV into DataFrame

# %% [markdown]
# ## Reservation Data 2010 - 2015

# %%
#Read 2010 through 2015 reservation data and load as dataframe
res_file_10_15= os.path.join("Data","ReservationData10_15.csv")
res_data_10_15_df = pd.read_csv(res_file_10_15)
res_data_10_15_df

# %%
#Check 2010 through 2015 reservation data types
res_data_10_15_df.dtypes

# %%
#Verify 2010 through 2015 reservation OrderNumber uniqueness
res_data_10_15_df.nunique()

# %% [markdown]
# ## Reservation Data 2016 - 2020

# %%
#Read 2016 through 2020 reservation data and load as dataframe
res_file_16_20= os.path.join("Data","ReservationData16_20.csv")
res_data_16_20_df = pd.read_csv(res_file_16_20)
res_data_16_20_df

# %%
#Verify 2010 through 2015 reservation OrderNumber uniqueness
#Duplicate OrderNumbers found
res_data_16_20_df.nunique()

# %%
#Filter out duplicate reservation Order Numbers, leaving only the first occurance 
res_data_16_20_clean_df=res_data_16_20_df.loc[res_data_16_20_df.duplicated(subset='OrderNumber',keep='first')==False,:]
res_data_16_20_clean_df

# %% [markdown]
# ## Geocode Data

# %%
#Read geocode data and load as dataframe
geo_file= os.path.join("Data","Reverse_GeocodeInfo.csv")
geo_df = pd.read_csv(geo_file)
geo_df

# %%
#Map RegionDescription for Colorado Nation Parks to match the nomenclature of the national parks data set
geo_df["RegionDescription"]=geo_df["RegionDescription"].\
replace(["Great Sand Dunes National Park","Mesa Verde National Park","Black Canyon National Park","Rocky Mountain National Park"],\
        ["Great Sand Dunes NP & PRES","Mesa Verde NP","Black Canyon of the Gunnison NP","Rocky Mountain NP"])

# %%
#Check that mapped RegionDescription changes have been applied
geo_df["RegionDescription"].unique()

# %%
#Drop null values for FacilityID
geo_clean_df=geo_df.loc[geo_df['FacilityID'].notna()==True,:]
geo_clean_df

# %% [markdown]
# ## National Park Visitor Data

# %%
#Read national park summary file data and load as DataFrame and check data types
nps_file= os.path.join("Data","NatPark_All_Clean_Summary_Visitor_Use.csv")
nps_df_0 = pd.read_csv(nps_file)

nps_df_0.dtypes
# Out:
# Park                        object
# State                       object
# Year                         int64
# Month                       object
# Recreation_Visitors         object
# Non_Recreation_Visitors     object
# Recreation_Visitor_Hours    object
# Non_Recreation_Hours        object
# Concession_Lodging          object
# Tent_Campers                object
# RV_Campers                  object
# Backcountry_Campers         object
# Misc_Campers                object
# Total_Overnight_Stays       object
# dtype: object

# %%
#Remove "," from sting values for each of the visitor counts
nps_df_0["Recreation_Visitors"]=nps_df_0["Recreation_Visitors"].str.replace(",","")
nps_df_0["Non_Recreation_Visitors"]=nps_df_0["Non_Recreation_Visitors"].str.replace(",","")
nps_df_0["Recreation_Visitor_Hours"]=nps_df_0["Recreation_Visitor_Hours"].str.replace(",","")
nps_df_0["Non_Recreation_Hours"]=nps_df_0["Non_Recreation_Hours"].str.replace(",","")
nps_df_0["Concession_Lodging"]=nps_df_0["Concession_Lodging"].str.replace(",","")
nps_df_0["Tent_Campers"]=nps_df_0["Tent_Campers"].str.replace(",","")
nps_df_0["RV_Campers"]=nps_df_0["RV_Campers"].str.replace(",","")
nps_df_0["Backcountry_Campers"]=nps_df_0["Backcountry_Campers"].str.replace(",","")
nps_df_0["Misc_Campers"]=nps_df_0["Misc_Campers"].str.replace(",","")
nps_df_0["Total_Overnight_Stays"]=nps_df_0["Total_Overnight_Stays"].str.replace(",","")

# %%
nps_df_0
# Out:
#                                 Park State  Year      Month  \
# 0    Black Canyon of the Gunnison NP    CO  2010    January
# 1    Black Canyon of the Gunnison NP    CO  2010   February
# 2    Black Canyon of the Gunnison NP    CO  2010      March
# 3    Black Canyon of the Gunnison NP    CO  2010      April
# 4    Black Canyon of the Gunnison NP    CO  2010        May
# ..                               ...   ...   ...        ...
# 523                Rocky Mountain NP    CO  2020     August
# 524                Rocky Mountain NP    CO  2020  September
# 525                Rocky Mountain NP    CO  2020    October
# 526                Rocky Mountain NP    CO  2020   November
# 527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 14 columns]

# %%
# data_dict={"Park": object,
#            "State": object,
#            "Year": int,
#            "Month": object,
#            "Recreation_ Visitors": int,
#            "Non_Recreation_Visitors": int,
#            "Recreation_Visitor_Hours": int,
#            "Non_Recreation_Hours": int,
#            "Concession_Lodging": int,
#            "Tent_Campers": int,
#            "RV_Campers": int,
#            "Backcountry_Campers": int,
#            "Misc_Campers": int,
#            "Total_Overnight_Stays": int
#           }

# %%
nps_df_1=nps_df_0.reset_index()

# %%
nps_df_1
# Out:
#      index                             Park State  Year      Month  \
# 0        0  Black Canyon of the Gunnison NP    CO  2010    January
# 1        1  Black Canyon of the Gunnison NP    CO  2010   February
# 2        2  Black Canyon of the Gunnison NP    CO  2010      March
# 3        3  Black Canyon of the Gunnison NP    CO  2010      April
# 4        4  Black Canyon of the Gunnison NP    CO  2010        May
# ..     ...                              ...   ...   ...        ...
# 523    523                Rocky Mountain NP    CO  2020     August
# 524    524                Rocky Mountain NP    CO  2020  September
# 525    525                Rocky Mountain NP    CO  2020    October
# 526    526                Rocky Mountain NP    CO  2020   November
# 527    527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 15 columns]

# %%
# nps_df_2=nps_df_1.rename(columns={"index":"uniqueid","Recreation_ Visitors":"Recreation_Visitors"})

nps_df_2=nps_df_1.rename(columns={"index":"uniqueid"})

# %%
nps_df_2
# Out:
#      uniqueid                             Park State  Year      Month  \
# 0           0  Black Canyon of the Gunnison NP    CO  2010    January
# 1           1  Black Canyon of the Gunnison NP    CO  2010   February
# 2           2  Black Canyon of the Gunnison NP    CO  2010      March
# 3           3  Black Canyon of the Gunnison NP    CO  2010      April
# 4           4  Black Canyon of the Gunnison NP    CO  2010        May
# ..        ...                              ...   ...   ...        ...
# 523       523                Rocky Mountain NP    CO  2020     August
# 524       524                Rocky Mountain NP    CO  2020  September
# 525       525                Rocky Mountain NP    CO  2020    October
# 526       526                Rocky Mountain NP    CO  2020   November
# 527       527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 15 columns]

# %%
# Change data type of all arithmetic columns to integers from objects
data_dict={"uniqueid": int,
           "Park": object,
           "State": object,
           "Year": int,
           "Month": object,
           "Recreation_Visitors": int,
           "Non_Recreation_Visitors": int,
           "Recreation_Visitor_Hours": int,
           "Non_Recreation_Hours": int,
           "Concession_Lodging": int,
           "Tent_Campers": int,
           "RV_Campers": int,
           "Backcountry_Campers": int,
           "Misc_Campers": int,
           "Total_Overnight_Stays": int
          }

nps_df=nps_df_2.astype(data_dict)

nps_df

nps_df.dtypes
# Out:
# uniqueid                     int32
# Park                        object
# State                       object
# Year                         int32
# Month                       object
# Recreation_Visitors          int32
# Non_Recreation_Visitors      int32
# Recreation_Visitor_Hours     int32
# Non_Recreation_Hours         int32
# Concession_Lodging           int32
# Tent_Campers                 int32
# RV_Campers                   int32
# Backcountry_Campers          int32
# Misc_Campers                 int32
# Total_Overnight_Stays        int32
# dtype: object

# %%
# {"park_1":{"Year":[],
#            "Month":[],
#            "Recreation_ Visitors":[],
#            "Year":[],
    
#             },
#  "park_2":{
    
# },
#  "park_3":{
    
# },
#  "park_4":{
    
# },
# }

# %%
# park_dict={}
# parks=list(nps_df["Park"].unique())
# parks

# %%
# for park in parks:
#     each_park_dict={'Year':list(nps_df[nps_df["Park"]==park]["Year"]),
#                     'Month':list(nps_df[nps_df["Park"]==park]["Month"]),
#                     'Visitors':list(nps_df[nps_df["Park"]==park]["Recreation_ Visitors"]),
#                     'Tent':list(nps_df[nps_df["Park"]==park]["Tent_Campers"]),
#                     'RV':list(nps_df[nps_df["Park"]==park]["RV_Campers"])
#                    }
#     park_dict[f'{park}']=each_park_dict
        
# park_dict

# %%
# list(nps_df[nps_df["Park"]==parks[0]]["Year"])

# %%
# nps_df_1.head()

# %%
# nps_df['UniqueID']=f"{nps_df['Park']}/{nps_df['State']}/{nps_df['Year']}/{nps_df['Month']}"
# nps_df

# %% [markdown]
# ## National Park Comments DataFrame

# %%
#Read national parks comments data and load as DataFrame
comments_file= os.path.join("Data","NatPark_All_Comments.csv")
comments_df_0 = pd.read_csv(comments_file)
comments_df_0

# %%
#Verify comments_df data types
comments_df_0.dtypes

# %%
# Add column wiht index values
comments_df_1=comments_df_0.reset_index()

# %%
comments_df=comments_df_1.rename(columns={"index":"uniqueid"})

# %%
comments_df

# %% [markdown]
# # Store DataFrame into PostgresSQL Database

# %% [markdown]
# ## Postgres SQL Connection

# %%
#Connect to PostgresSQL database and create engine
rds_connection_string = (f'postgres:postgres@localhost:5432/dfcl071kkkkeuj')
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Connect to PostgresSQL database and create engine
#rds_connection_string = (f'postgres://ntjilcynnqsoia:b3117a615652e2afced26ed774d8adeffec9692481fce0288d90e6a3c959411e@ec2-23-21-229-200.compute-1.amazonaws.com:5432/dfcl071kkkkeuj')
#engine = create_engine(f'postgresql://{rds_connection_string}')
#engine = create_engine(rds_connection_string.replace('://', 'ql://'))

# %%
#Retrieve table names from PostgresSQL database
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "dfcl071kkkkeuj" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-c905a2a99aca> in <module>
#       1 #Retrieve table names from PostgresSQL database
# ----> 2 engine.table_names()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2314         """
#    2315
# -> 2316         with self._optional_conn_ctx_manager(connection) as conn:
#    2317             return self.dialect.get_table_names(conn, schema)
#    2318
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2084     def _optional_conn_ctx_manager(self, connection=None):
#    2085         if connection is None:
# -> 2086             with self._contextual_connect() as conn:
#    2087                 yield conn
#    2088         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "dfcl071kkkkeuj" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## 2010 to 2015 Reservation Data

# %%
#Append 2010 through 2015 reservation data into SQL database table:reservations
res_data_10_15_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %%
# import math
# batch_size=100000
# beg=0
# end=beg+batch_size
# for i in range(math.floor(len(res_df)/batch_size)): 
#     print(f'{beg} - {end}')
#     res_df.iloc[beg:end].to_sql(name='reservations', con=engine, if_exists='append', index=False)
#     beg=end
#     end=beg+batch_size
# res_df.iloc[end:].to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## 2016 to 2020 Reservation Data

# %%
#Append 2016 through 2020 reservation data into SQL database table: reservations
res_data_16_20_clean_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## National Parks DataFrame to Database

# %%
#Append national parks summary data into SQL database table: nps_summary
nps_df.to_sql(name='nps_summary', con=engine, if_exists='append', index=False)

# with engine.connect() as con:
#     con.execute('ALTER TABLE nps_summary ADD PRIMARY KEY (ID);')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "dfcl071kkkkeuj" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-62fd4c437b2e> in <module>
#       1 #Append national parks summary data into SQL database table: nps_summary
# ----> 2 nps_df.to_sql(name='nps_summary', con=engine, if_exists='append', index=False)
#       3
#       4 # with engine.connect() as con:
#       5 #     con.execute('ALTER TABLE nps_summary ADD PRIMARY KEY (ID);')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     719
#     720     def create(self):
# --> 721         if self.exists():
#     722             if self.if_exists == "fail":
#     723                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     706
#     707     def exists(self):
# --> 708         return self.pd_sql.has_table(self.name, self.schema)
#     709
#     710     def sql_schema(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1428
#    1429     def has_table(self, name, schema=None):
# -> 1430         return self.connectable.run_callable(
#    1431             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1432         )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "dfcl071kkkkeuj" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## Geocode DataFrame to Database

# %%
#Append geocode data into SQL database table: geocode_info
geo_clean_df.to_sql(name='geocode_info', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## National Park Comments DataFrame to Database

# %%
#Append national parks comment data into SQL database table: nps_comments
comments_df.to_sql(name='nps_comments', con=engine, if_exists='append', index=False)
