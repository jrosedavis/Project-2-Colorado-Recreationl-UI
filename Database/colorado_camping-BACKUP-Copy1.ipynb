# %%
import pandas as pd
from sqlalchemy import create_engine
import os

import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import psycopg2
from sqlalchemy import inspect

# %%
pg_user = 'postgres'
pg_pwd = 'postgres'
pg_port = "5432"
database = 'colorado_camping_db'
url = f"postgresql://{pg_user}:{pg_pwd}@localhost:{pg_port}/{database}"
engine = create_engine(f'{url}')
# reflect an existing database into a new model

insp=inspect(engine)

print(insp.get_table_names())

Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
nps = Base.classes.geocode_info

session = Session(engine)

result=session.query(nps)\
.filter(nps.FacilityID==231860).all()

for each_result in result:
    print(each_result.FacilityLatitude)
# Out:
# ['nps_summary', 'reservations', 'nps_comments', 'geocode_info']

# %% [markdown]
# # Store CSV into DataFrame

# %% [markdown]
# ## Reservation Data 2010 - 2015

# %%
#Read 2010 through 2015 reservation data and load as dataframe
res_file_10_15= os.path.join("Data","ReservationData10_15.csv")
res_data_10_15_df = pd.read_csv(res_file_10_15)
res_data_10_15_df
# Out:
#        OrderNumber                          Park  \
# 0       2-13888626      GLACIER BASIN CAMPGROUND
# 1       2-13883425  BOGAN FLATS CAMPGROUND GRP S
# 2       2-13884441      BELLAIRE LAKE CAMPGROUND
# 3       2-13887874      GLACIER BASIN CAMPGROUND
# 4       2-13887885            BUFFALO CAMPGROUND
# ...            ...                           ...
# 472744  2-32660704         GORE CREEK CAMPGROUND
# 472745  2-32656250                 ROBERTS CABIN
# 472746  2-32657290       MORAINE PARK CAMPGROUND
# 472747  2-32657310                SPRINGER GULCH
# 472748  2-32657321          DIFFICULT CAMPGROUND
#
#                                 SiteType  FacilityID FacilityState  StartDate  \
# 0       GROUP TENT ONLY AREA NONELECTRIC      232462            CO  8/12/2010
# 1                   STANDARD NONELECTRIC      232158            CO   9/3/2010
# 2                      STANDARD ELECTRIC      233137            CO  8/24/2010
# 3                   STANDARD NONELECTRIC      232462            CO   8/7/2010
# 4                   STANDARD NONELECTRIC      231875            CO  8/13/2010
# ...                                  ...         ...           ...        ...
# 472744             TENT ONLY NONELECTRIC      234794            CO  9/18/2015
# 472745                 CABIN NONELECTRIC      233808            CO  10/6/2015
# 472746                           WALK TO      232463            CO  9/13/2015
# 472747              STANDARD NONELECTRIC      233718            CO  9/18/2015
# 472748              STANDARD NONELECTRIC      231880            CO  9/20/2015
#
#           EndDate  NumberOfPeople
# 0       8/13/2010              17
# 1        9/6/2010               6
# 2       8/27/2010               2
# 3        8/8/2010               1
# 4       8/15/2010               6
# ...           ...             ...
# 472744  9/20/2015               2
# 472745  10/9/2015               2
# 472746  9/16/2015               1
# 472747  9/21/2015               4
# 472748  9/24/2015               2
#
# [472749 rows x 8 columns]

# %%
#Check 2010 through 2015 reservation data types
res_data_10_15_df.dtypes
# Out:
# OrderNumber       object
# Park              object
# SiteType          object
# FacilityID         int64
# FacilityState     object
# StartDate         object
# EndDate           object
# NumberOfPeople     int64
# dtype: object

# %%
#Verify 2010 through 2015 reservation OrderNumber uniqueness
res_data_10_15_df.nunique()
# Out:
# OrderNumber       472749
# Park                 189
# SiteType              17
# FacilityID           189
# FacilityState          1
# StartDate           1766
# EndDate             1776
# NumberOfPeople        89
# dtype: int64

# %% [markdown]
# ## Reservation Data 2016 - 2020

# %%
#Read 2016 through 2020 reservation data and load as dataframe
res_file_16_20= os.path.join("Data","ReservationData16_20.csv")
res_data_16_20_df = pd.read_csv(res_file_16_20)
res_data_16_20_df
# Out:
#          OrderNumber                           Park  \
# 0         2-32735678          SADDLEHORN CAMPGROUND
# 1         2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2         2-32736183            CUTTHROAT BAY GROUP
# 3         2-32734610         Pinon Flats Campground
# 4         2-32737179          SADDLEHORN CAMPGROUND
# ...              ...                            ...
# 701027  0299021752-1  BUCKEYE RECREATION AREA (CO)
# 701028  0299110351-1  BUCKEYE RECREATION AREA (CO)
# 701029  0299113958-1  BUCKEYE RECREATION AREA (CO)
# 701030  0299604686-1  BUCKEYE RECREATION AREA (CO)
# 701031  0299699639-1  BUCKEYE RECREATION AREA (CO)
#
#                                 SiteType  FacilityID FacilityState  \
# 0                   STANDARD NONELECTRIC      234778            CO
# 1             GROUP STANDARD NONELECTRIC      233318            CO
# 2             GROUP STANDARD NONELECTRIC      233880            CO
# 3       GROUP TENT ONLY AREA NONELECTRIC      234685            CO
# 4                   STANDARD NONELECTRIC      234778            CO
# ...                                  ...         ...           ...
# 701027              STANDARD NONELECTRIC      234724            CO
# 701028              STANDARD NONELECTRIC      234724            CO
# 701029              STANDARD NONELECTRIC      234724            CO
# 701030   GROUP STANDARD AREA NONELECTRIC      234724            CO
# 701031              STANDARD NONELECTRIC      234724            CO
#
#          StartDate     EndDate  NumberOfPeople
# 0        10/9/2015  10/11/2015               1
# 1         7/7/2016   7/10/2016              75
# 2        7/15/2016   7/17/2016              30
# 3       10/23/2015  10/25/2015              20
# 4        10/3/2015   10/4/2015               2
# ...            ...         ...             ...
# 701027   7/24/2020   7/26/2020               4
# 701028   7/21/2020   7/22/2020               1
# 701029   5/25/2020   5/26/2020               2
# 701030   7/17/2020   7/19/2020              25
# 701031   9/20/2020   9/22/2020               1
#
# [701032 rows x 8 columns]

# %%
#Verify 2010 through 2015 reservation OrderNumber uniqueness
#Duplicate OrderNumbers found
res_data_16_20_df.nunique()
# Out:
# OrderNumber       698948
# Park                 368
# SiteType              17
# FacilityID           198
# FacilityState          1
# StartDate           1761
# EndDate             1783
# NumberOfPeople        92
# dtype: int64

# %%
#Filter out duplicate reservation Order Numbers, leaving only the first occurance 
res_data_16_20_clean_df=res_data_16_20_df.loc[res_data_16_20_df.duplicated(subset='OrderNumber',keep='first')==False,:]
res_data_16_20_clean_df
# Out:
#          OrderNumber                           Park  \
# 0         2-32735678          SADDLEHORN CAMPGROUND
# 1         2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2         2-32736183            CUTTHROAT BAY GROUP
# 3         2-32734610         Pinon Flats Campground
# 4         2-32737179          SADDLEHORN CAMPGROUND
# ...              ...                            ...
# 701027  0299021752-1  BUCKEYE RECREATION AREA (CO)
# 701028  0299110351-1  BUCKEYE RECREATION AREA (CO)
# 701029  0299113958-1  BUCKEYE RECREATION AREA (CO)
# 701030  0299604686-1  BUCKEYE RECREATION AREA (CO)
# 701031  0299699639-1  BUCKEYE RECREATION AREA (CO)
#
#                                 SiteType  FacilityID FacilityState  \
# 0                   STANDARD NONELECTRIC      234778            CO
# 1             GROUP STANDARD NONELECTRIC      233318            CO
# 2             GROUP STANDARD NONELECTRIC      233880            CO
# 3       GROUP TENT ONLY AREA NONELECTRIC      234685            CO
# 4                   STANDARD NONELECTRIC      234778            CO
# ...                                  ...         ...           ...
# 701027              STANDARD NONELECTRIC      234724            CO
# 701028              STANDARD NONELECTRIC      234724            CO
# 701029              STANDARD NONELECTRIC      234724            CO
# 701030   GROUP STANDARD AREA NONELECTRIC      234724            CO
# 701031              STANDARD NONELECTRIC      234724            CO
#
#          StartDate     EndDate  NumberOfPeople
# 0        10/9/2015  10/11/2015               1
# 1         7/7/2016   7/10/2016              75
# 2        7/15/2016   7/17/2016              30
# 3       10/23/2015  10/25/2015              20
# 4        10/3/2015   10/4/2015               2
# ...            ...         ...             ...
# 701027   7/24/2020   7/26/2020               4
# 701028   7/21/2020   7/22/2020               1
# 701029   5/25/2020   5/26/2020               2
# 701030   7/17/2020   7/19/2020              25
# 701031   9/20/2020   9/22/2020               1
#
# [698948 rows x 8 columns]

# %% [markdown]
# ## Geocode Data

# %%
#Read geocode data and load as dataframe
geo_file= os.path.join("Data","Reverse_GeocodeInfo.csv")
geo_df = pd.read_csv(geo_file)
geo_df
# Out:
#                               RegionDescription  \
# 0                    Colorado National Monument
# 1                   PAGOSA Ranger District (CO)
# 2                               SULPHUR RD - FS
# 3                                Comanche RD-FS
# 4                Great Sand Dunes National Park
# ..                                          ...
# 192                          GRAND VALLEY RD-FS
# 193  McInnis Canyons National Conservation Area
# 194                          GRAND VALLEY RD-FS
# 195                           SAN CARLOS RD -FS
# 196                          GRAND VALLEY RD-FS
#
#                                          Park  FacilityID FacilityState  \
# 0                       SADDLEHORN CAMPGROUND    234778.0            CO
# 1               BLANCO RIVER GROUP CAMPGROUND    233318.0            CO
# 2                         CUTTHROAT BAY GROUP    233880.0            CO
# 3    Picket Wire Canyonlands Guided Auto Tour    234166.0            CO
# 4                      Pinon Flats Campground    234685.0            CO
# ..                                        ...         ...           ...
# 192                                 OAK CABIN    234666.0            CO
# 193            Ruby Horsethief Canyon Permits         NaN            CO
# 194                                ASPEN LEAF    234664.0            CO
# 195                      DAVENPORT CAMPGROUND    234684.0            CO
# 196                                BLACK BEAR    233216.0            CO
#
#      FacilityLongitude  FacilityLatitude       CityPlace            County
# 0             -108.733           39.1048          Fruita       Mesa County
# 1             -106.883           37.1453  Pagosa Springs  Archuleta County
# 2             -105.874           40.1914          Granby      Grand County
# 3             -103.524           37.9857        La Junta      Otero County
# 4             -105.517           37.7333      Westcliffe     Custer County
# ..                 ...               ...             ...               ...
# 192           -108.674           38.6506    Orchard Mesa       Mesa County
# 193           -108.533           39.1194       Fruitvale       Mesa County
# 194           -108.674           38.6506    Orchard Mesa       Mesa County
# 195           -105.070           38.0556   Colorado City     Pueblo County
# 196           -108.081           39.0522       Cedaredge      Delta County
#
# [197 rows x 8 columns]

# %%
#Map RegionDescription for Colorado Nation Parks to match the nomenclature of the national parks data set
geo_df["RegionDescription"]=geo_df["RegionDescription"].\
replace(["Great Sand Dunes National Park","Mesa Verde National Park","Black Canyon National Park","Rocky Mountain National Park"],\
        ["Great Sand Dunes NP & PRES","Mesa Verde NP","Black Canyon of the Gunnison NP","Rocky Mountain NP"])

# %%
#Check that mapped RegionDescription changes have been applied
geo_df["RegionDescription"].unique()
# Out:
# array(['Colorado National Monument', 'PAGOSA Ranger District (CO)',
#        'SULPHUR RD - FS', 'Comanche RD-FS', 'Great Sand Dunes NP & PRES',
#        'DILLON RD - FS', 'CLEAR CREEK RD -FS', 'SAGUACHE RD -FS',
#        'CONEJOS PEAK RD -FS', 'LEADVILLE RD - FS', 'PIKES PEAK RD -FS',
#        'Curecanti National Recreation Area', 'SOUTH PARK RD -FS',
#        'Mesa Verde NP', 'ASPEN RD -FS', 'HAHNS P/BEARS EARS RD -FS',
#        'SAN CARLOS RD -FS', 'NORWOOD RD - FS', 'CANYON LAKES RD -FS',
#        'PARKS RD - FS', 'SALIDA RD - FS', 'COLUMBINE RD -FS',
#        'DIVIDE RD -FS', 'HOLY CROSS RD -FS', 'MANCOS/DELORES RD -FS',
#        'SOPRIS RD - FS', 'Rocky Mountain NP',
#        'Black Canyon of the Gunnison NP', 'BOULDER RD',
#        'SOUTH PLATTE RD-FS', 'MONTICELLO RD -FS',
#        "PAWNEE NAT'L GRASS -FS", 'Dinosaur National Monument',
#        'GUNNISON RD - FS', 'OURAY RD - FS', 'GRAND VALLEY RD-FS',
#        'BLANCO RD -FS', 'McInnis Canyons National Conservation Area'],
#       dtype=object)

# %%
#Drop null values for FacilityID
geo_clean_df=geo_df.loc[geo_df['FacilityID'].notna()==True,:]
geo_clean_df
# Out:
#                RegionDescription                                      Park  \
# 0     Colorado National Monument                     SADDLEHORN CAMPGROUND
# 1    PAGOSA Ranger District (CO)             BLANCO RIVER GROUP CAMPGROUND
# 2                SULPHUR RD - FS                       CUTTHROAT BAY GROUP
# 3                 Comanche RD-FS  Picket Wire Canyonlands Guided Auto Tour
# 4     Great Sand Dunes NP & PRES                    Pinon Flats Campground
# ..                           ...                                       ...
# 191  PAGOSA Ranger District (CO)                 WILLIAMS CREEK CAMPGROUND
# 192           GRAND VALLEY RD-FS                                 OAK CABIN
# 194           GRAND VALLEY RD-FS                                ASPEN LEAF
# 195            SAN CARLOS RD -FS                      DAVENPORT CAMPGROUND
# 196           GRAND VALLEY RD-FS                                BLACK BEAR
#
#      FacilityID FacilityState  FacilityLongitude  FacilityLatitude  \
# 0      234778.0            CO           -108.733           39.1048
# 1      233318.0            CO           -106.883           37.1453
# 2      233880.0            CO           -105.874           40.1914
# 3      234166.0            CO           -103.524           37.9857
# 4      234685.0            CO           -105.517           37.7333
# ..          ...           ...                ...               ...
# 191    251844.0            CO           -107.227           37.4952
# 192    234666.0            CO           -108.674           38.6506
# 194    234664.0            CO           -108.674           38.6506
# 195    234684.0            CO           -105.070           38.0556
# 196    233216.0            CO           -108.081           39.0522
#
#           CityPlace            County
# 0            Fruita       Mesa County
# 1    Pagosa Springs  Archuleta County
# 2            Granby      Grand County
# 3          La Junta      Otero County
# 4        Westcliffe     Custer County
# ..              ...               ...
# 191  Pagosa Springs  Archuleta County
# 192    Orchard Mesa       Mesa County
# 194    Orchard Mesa       Mesa County
# 195   Colorado City     Pueblo County
# 196       Cedaredge      Delta County
#
# [196 rows x 8 columns]

# %% [markdown]
# ## National Park Visitor Data

# %%
#Read national park summary file data and load as DataFrame and check data types
nps_file= os.path.join("Data","NatPark_All_Clean_Summary_Visitor_Use.csv")
nps_df_0 = pd.read_csv(nps_file)

nps_df_0.dtypes
# Out:
# Park                        object
# State                       object
# Year                         int64
# Month                       object
# Recreation_Visitors         object
# Non_Recreation_Visitors     object
# Recreation_Visitor_Hours    object
# Non_Recreation_Hours        object
# Concession_Lodging          object
# Tent_Campers                object
# RV_Campers                  object
# Backcountry_Campers         object
# Misc_Campers                object
# Total_Overnight_Stays       object
# dtype: object

# %%
#Remove "," from sting values for each of the visitor counts
nps_df_0["Recreation_Visitors"]=nps_df_0["Recreation_Visitors"].str.replace(",","")
nps_df_0["Non_Recreation_Visitors"]=nps_df_0["Non_Recreation_Visitors"].str.replace(",","")
nps_df_0["Recreation_Visitor_Hours"]=nps_df_0["Recreation_Visitor_Hours"].str.replace(",","")
nps_df_0["Non_Recreation_Hours"]=nps_df_0["Non_Recreation_Hours"].str.replace(",","")
nps_df_0["Concession_Lodging"]=nps_df_0["Concession_Lodging"].str.replace(",","")
nps_df_0["Tent_Campers"]=nps_df_0["Tent_Campers"].str.replace(",","")
nps_df_0["RV_Campers"]=nps_df_0["RV_Campers"].str.replace(",","")
nps_df_0["Backcountry_Campers"]=nps_df_0["Backcountry_Campers"].str.replace(",","")
nps_df_0["Misc_Campers"]=nps_df_0["Misc_Campers"].str.replace(",","")
nps_df_0["Total_Overnight_Stays"]=nps_df_0["Total_Overnight_Stays"].str.replace(",","")

# %%
nps_df_0
# Out:
#                                 Park State  Year      Month  \
# 0    Black Canyon of the Gunnison NP    CO  2010    January
# 1    Black Canyon of the Gunnison NP    CO  2010   February
# 2    Black Canyon of the Gunnison NP    CO  2010      March
# 3    Black Canyon of the Gunnison NP    CO  2010      April
# 4    Black Canyon of the Gunnison NP    CO  2010        May
# ..                               ...   ...   ...        ...
# 523                Rocky Mountain NP    CO  2020     August
# 524                Rocky Mountain NP    CO  2020  September
# 525                Rocky Mountain NP    CO  2020    October
# 526                Rocky Mountain NP    CO  2020   November
# 527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 14 columns]

# %%
# data_dict={"Park": object,
#            "State": object,
#            "Year": int,
#            "Month": object,
#            "Recreation_ Visitors": int,
#            "Non_Recreation_Visitors": int,
#            "Recreation_Visitor_Hours": int,
#            "Non_Recreation_Hours": int,
#            "Concession_Lodging": int,
#            "Tent_Campers": int,
#            "RV_Campers": int,
#            "Backcountry_Campers": int,
#            "Misc_Campers": int,
#            "Total_Overnight_Stays": int
#           }

# %%
nps_df_1=nps_df_0.reset_index()

# %%
nps_df_1
# Out:
#      index                             Park State  Year      Month  \
# 0        0  Black Canyon of the Gunnison NP    CO  2010    January
# 1        1  Black Canyon of the Gunnison NP    CO  2010   February
# 2        2  Black Canyon of the Gunnison NP    CO  2010      March
# 3        3  Black Canyon of the Gunnison NP    CO  2010      April
# 4        4  Black Canyon of the Gunnison NP    CO  2010        May
# ..     ...                              ...   ...   ...        ...
# 523    523                Rocky Mountain NP    CO  2020     August
# 524    524                Rocky Mountain NP    CO  2020  September
# 525    525                Rocky Mountain NP    CO  2020    October
# 526    526                Rocky Mountain NP    CO  2020   November
# 527    527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 15 columns]

# %%
# nps_df_2=nps_df_1.rename(columns={"index":"uniqueid","Recreation_ Visitors":"Recreation_Visitors"})

nps_df_2=nps_df_1.rename(columns={"index":"uniqueid"})

# %%
nps_df_2
# Out:
#      uniqueid                             Park State  Year      Month  \
# 0           0  Black Canyon of the Gunnison NP    CO  2010    January
# 1           1  Black Canyon of the Gunnison NP    CO  2010   February
# 2           2  Black Canyon of the Gunnison NP    CO  2010      March
# 3           3  Black Canyon of the Gunnison NP    CO  2010      April
# 4           4  Black Canyon of the Gunnison NP    CO  2010        May
# ..        ...                              ...   ...   ...        ...
# 523       523                Rocky Mountain NP    CO  2020     August
# 524       524                Rocky Mountain NP    CO  2020  September
# 525       525                Rocky Mountain NP    CO  2020    October
# 526       526                Rocky Mountain NP    CO  2020   November
# 527       527                Rocky Mountain NP    CO  2020   December
#
#     Recreation_Visitors Non_Recreation_Visitors Recreation_Visitor_Hours  \
# 0                  2519                       0                     6898
# 1                  3034                       0                     9193
# 2                  3199                       0                     8741
# 3                  4421                       0                    17747
# 4                 21259                       0                   128429
# ..                  ...                     ...                      ...
# 523              580368                    2300                  3963040
# 524              500019                    1500                  3316384
# 525              297665                     560                  1839907
# 526              157875                     100                   948387
# 527              156165                      60                   944415
#
#     Non_Recreation_Hours Concession_Lodging Tent_Campers RV_Campers  \
# 0                      0                  0           19          8
# 1                      0                  0           35         13
# 2                      0                  0           35         20
# 3                      0                  0          169        160
# 4                      0                  0         1159        715
# ..                   ...                ...          ...        ...
# 523                 6900                  0         7506      10212
# 524                 4500                  0         7776       5253
# 525                 1680                  0          984        756
# 526                  300                  0            0          0
# 527                  180                  0          183        180
#
#     Backcountry_Campers Misc_Campers Total_Overnight_Stays
# 0                     0            0                    27
# 1                     0            0                    48
# 2                     0            0                    55
# 3                    32            0                   361
# 4                   107            0                  1981
# ..                  ...          ...                   ...
# 523               12334            0                 30052
# 524                6738            0                 19767
# 525                1630            0                  3370
# 526                  71            0                    71
# 527                 101            0                   464
#
# [528 rows x 15 columns]

# %%
# Change data type of all arithmetic columns to integers from objects
data_dict={"uniqueid": int,
           "Park": object,
           "State": object,
           "Year": int,
           "Month": object,
           "Recreation_Visitors": int,
           "Non_Recreation_Visitors": int,
           "Recreation_Visitor_Hours": int,
           "Non_Recreation_Hours": int,
           "Concession_Lodging": int,
           "Tent_Campers": int,
           "RV_Campers": int,
           "Backcountry_Campers": int,
           "Misc_Campers": int,
           "Total_Overnight_Stays": int
          }

nps_df=nps_df_2.astype(data_dict)

nps_df

nps_df.dtypes
# Out:
# uniqueid                     int32
# Park                        object
# State                       object
# Year                         int32
# Month                       object
# Recreation_Visitors          int32
# Non_Recreation_Visitors      int32
# Recreation_Visitor_Hours     int32
# Non_Recreation_Hours         int32
# Concession_Lodging           int32
# Tent_Campers                 int32
# RV_Campers                   int32
# Backcountry_Campers          int32
# Misc_Campers                 int32
# Total_Overnight_Stays        int32
# dtype: object

# %%
# {"park_1":{"Year":[],
#            "Month":[],
#            "Recreation_ Visitors":[],
#            "Year":[],
    
#             },
#  "park_2":{
    
# },
#  "park_3":{
    
# },
#  "park_4":{
    
# },
# }

# %%
# park_dict={}
# parks=list(nps_df["Park"].unique())
# parks

# %%
# for park in parks:
#     each_park_dict={'Year':list(nps_df[nps_df["Park"]==park]["Year"]),
#                     'Month':list(nps_df[nps_df["Park"]==park]["Month"]),
#                     'Visitors':list(nps_df[nps_df["Park"]==park]["Recreation_ Visitors"]),
#                     'Tent':list(nps_df[nps_df["Park"]==park]["Tent_Campers"]),
#                     'RV':list(nps_df[nps_df["Park"]==park]["RV_Campers"])
#                    }
#     park_dict[f'{park}']=each_park_dict
        
# park_dict

# %%
# list(nps_df[nps_df["Park"]==parks[0]]["Year"])

# %%
# nps_df_1.head()

# %%
# nps_df['UniqueID']=f"{nps_df['Park']}/{nps_df['State']}/{nps_df['Year']}/{nps_df['Month']}"
# nps_df

# %% [markdown]
# ## National Park Comments DataFrame

# %%
#Read national parks comments data and load as DataFrame
comments_file= os.path.join("Data","NatPark_All_Comments.csv")
comments_df_0 = pd.read_csv(comments_file)
comments_df_0
# Out:
#                                 Park State  Year CollectedDate  \
# 0                      Mesa Verde NP    CO  2010      1/1/2010
# 1         Great Sand Dunes NP & PRES    CO  2010      3/1/2010
# 2         Great Sand Dunes NP & PRES    CO  2010      6/1/2010
# 3                      Mesa Verde NP    CO  2010     10/1/2010
# 4                  Rocky Mountain NP    CO  2010     10/1/2010
# ..                               ...   ...   ...           ...
# 214  Black Canyon of the Gunnison NP    CO  2020     10/1/2020
# 215                Rocky Mountain NP    CO  2020     11/1/2020
# 216  Black Canyon of the Gunnison NP    CO  2020     11/1/2020
# 217                Rocky Mountain NP    CO  2020     12/1/2020
# 218  Black Canyon of the Gunnison NP    CO  2020     12/1/2020
#
#                                               Comments
# 0            Park closed January 21-24 due to weather.
# 1    Our campground was closed in March 2010 for se...
# 2    There was a forest fire in the northern part o...
# 3    Morefield Campground closed for the season Oct...
# 4    Much of October 2010 was unseasonably warm, es...
# ..                                                 ...
# 214  No bus tours due to COVID. Outdoor only VC acc...
# 215  RMNP was closed due to the East Troublesome Wi...
# 216  North Rim Ranger Station closed in both the in...
# 217  RMNP was closed due to the East Troublesome Wi...
# 218                       North Rim closed due to snow
#
# [219 rows x 5 columns]

# %%
#Verify comments_df data types
comments_df_0.dtypes
# Out:
# Park             object
# State            object
# Year              int64
# CollectedDate    object
# Comments         object
# dtype: object

# %%
# Add column wiht index values
comments_df_1=comments_df_0.reset_index()

# %%
comments_df=comments_df_1.rename(columns={"index":"uniqueid"})

# %%
comments_df
# Out:
#      uniqueid                             Park State  Year CollectedDate  \
# 0           0                    Mesa Verde NP    CO  2010      1/1/2010
# 1           1       Great Sand Dunes NP & PRES    CO  2010      3/1/2010
# 2           2       Great Sand Dunes NP & PRES    CO  2010      6/1/2010
# 3           3                    Mesa Verde NP    CO  2010     10/1/2010
# 4           4                Rocky Mountain NP    CO  2010     10/1/2010
# ..        ...                              ...   ...   ...           ...
# 214       214  Black Canyon of the Gunnison NP    CO  2020     10/1/2020
# 215       215                Rocky Mountain NP    CO  2020     11/1/2020
# 216       216  Black Canyon of the Gunnison NP    CO  2020     11/1/2020
# 217       217                Rocky Mountain NP    CO  2020     12/1/2020
# 218       218  Black Canyon of the Gunnison NP    CO  2020     12/1/2020
#
#                                               Comments
# 0            Park closed January 21-24 due to weather.
# 1    Our campground was closed in March 2010 for se...
# 2    There was a forest fire in the northern part o...
# 3    Morefield Campground closed for the season Oct...
# 4    Much of October 2010 was unseasonably warm, es...
# ..                                                 ...
# 214  No bus tours due to COVID. Outdoor only VC acc...
# 215  RMNP was closed due to the East Troublesome Wi...
# 216  North Rim Ranger Station closed in both the in...
# 217  RMNP was closed due to the East Troublesome Wi...
# 218                       North Rim closed due to snow
#
# [219 rows x 6 columns]

# %% [markdown]
# # Store DataFrame into PostgresSQL Database

# %% [markdown]
# ## Postgres SQL Connection

# %%
#Connect to PostgresSQL database and create engine
rds_connection_string = (f'postgres:postgres@localhost:5432/colorado_camping_db')
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Retrieve table names from PostgresSQL database
engine.table_names()
# Out:
# ['nps_summary', 'reservations', 'nps_comments', 'geocode_info']

# %% [markdown]
# ## 2010 to 2015 Reservation Data

# %%
#Append 2010 through 2015 reservation data into SQL database table:reservations
res_data_10_15_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %%
# import math
# batch_size=100000
# beg=0
# end=beg+batch_size
# for i in range(math.floor(len(res_df)/batch_size)): 
#     print(f'{beg} - {end}')
#     res_df.iloc[beg:end].to_sql(name='reservations', con=engine, if_exists='append', index=False)
#     beg=end
#     end=beg+batch_size
# res_df.iloc[end:].to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## 2016 to 2020 Reservation Data

# %%
#Append 2016 through 2020 reservation data into SQL database table: reservations
res_data_16_20_clean_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## National Parks DataFrame to Database

# %%
#Append national parks summary data into SQL database table: nps_summary
nps_df.to_sql(name='nps_summary', con=engine, if_exists='append', index=False)

# with engine.connect() as con:
#     con.execute('ALTER TABLE nps_summary ADD PRIMARY KEY (ID);')

# %% [markdown]
# ## Geocode DataFrame to Database

# %%
#Append geocode data into SQL database table: geocode_info
geo_clean_df.to_sql(name='geocode_info', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## National Park Comments DataFrame to Database

# %%
#Append national parks comment data into SQL database table: nps_comments
comments_df.to_sql(name='nps_comments', con=engine, if_exists='append', index=False)
